# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-5, 5, 500)
k = 3
plt.plot(x, np.cos(x), label='kkk')
plt.plot(x, np.cos(k*x))
plt.xlabel("Переменная x")
plt.ylabel("Функция f(x)")
plt.show()
